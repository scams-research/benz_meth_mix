# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
sims = ['M', 'B']
mode = ['tumble', 'tns']
colors = ['red','blue']

# %%
for m in mode:
    for s in sims:
        data = np.loadtxt(f'/home/b35bh/joe3010.b35bh/project/joe_edit/analysis/transfer_analysis/data/racf/290_{s}/{m}.txt', delimiter=',')

        mean = data[0,:]
        std = data[1,:]
        sterr = data[2,:]
        t = data[3,:]
# Out:
#   Cell In[40], line 5
#     [f'mean{s}{m}'] = data[0,:]
#      ^
# SyntaxError: cannot assign to f-string expression

# %%
data_tumble_290_M = np.loadtxt(f'/home/b35bh/joe3010.b35bh/project/joe_edit/analysis/transfer_analysis/data/racf/290_M/tumble.txt', delimiter=',')
data_tns_290_M = np.loadtxt(f'/home/b35bh/joe3010.b35bh/project/joe_edit/analysis/transfer_analysis/data/racf/290_M/tns.txt', delimiter=',')

data_tumble_290_B = np.loadtxt(f'/home/b35bh/joe3010.b35bh/project/joe_edit/analysis/transfer_analysis/data/racf/290_B/tumble.txt', delimiter=',')
data_tns_290_B = np.loadtxt(f'/home/b35bh/joe3010.b35bh/project/joe_edit/analysis/transfer_analysis/data/racf/290_B/tns.txt', delimiter=',')


mean_tns_B = data_tns_290_B[0,:]
mean_tumble_M = data_tumble_290_M[0,:]
mean_tns_M = data_tns_290_M[0,:]
mean_tumble_B = data_tumble_290_B[0,:]

std_tns_B = data_tns_290_B[1,:]
std_tumble_M = data_tumble_290_M[1,:]
std_tns_M = data_tns_290_M[1,:]
std_tumble_B = data_tumble_290_B[1,:]

sterr_tns_B = data_tns_290_B[2,:]
sterr_tumble_M = data_tumble_290_M[2,:]
sterr_tns_M = data_tns_290_M[2,:]
sterr_tumble_B = data_tumble_290_B[2,:]

t_tns_B = data_tns_290_B[3,:]
t_tumble_B = data_tumble_290_B[3,:]
t_tns_M = data_tns_290_M[3,:]
t_tumble_M = data_tumble_290_M[3,:]

fig, ax = plt.subplots(1, 2, figsize=(12, 5), sharey=True)


ax[0].plot(t_tumble_M, mean_tumble_M, label='Benzene and methanol', color='orange', alpha=1)
ax[0].plot(t_tumble_B, mean_tumble_B, label='Benzene', color='red', alpha=1)

ax[1].plot(t_tns_M, mean_tns_M, label='Benzene and methanol', color='orange', alpha=1)
ax[1].plot(t_tns_B, mean_tns_B, label='Benzene', color='red', alpha=1)

ax[0].set_title('Tumble autocorrelation function')
ax[1].set_title('Tumble and spinning autocorrelation function')

ax[0].set_xlabel('time / ps')
ax[1].set_xlabel('time / ps')

ax[0].set_ylabel('rotation autocorrelation function')
ax[1].set_ylabel('rotation autocorrelation function')
ax[0].legend()
ax[1].legend()

# %%
data_tumble_290_M = np.loadtxt(f'/home/b35bh/joe3010.b35bh/project/joe_edit/analysis/transfer_analysis/data/racf/290_M/tumble.txt', delimiter=',')
data_tns_290_M = np.loadtxt(f'/home/b35bh/joe3010.b35bh/project/joe_edit/analysis/transfer_analysis/data/racf/290_M/tns.txt', delimiter=',')

data_tumble_290_B = np.loadtxt(f'/home/b35bh/joe3010.b35bh/project/joe_edit/analysis/transfer_analysis/data/racf/290_B/tumble.txt', delimiter=',')
data_tns_290_B = np.loadtxt(f'/home/b35bh/joe3010.b35bh/project/joe_edit/analysis/transfer_analysis/data/racf/290_B/tns.txt', delimiter=',')


mean_tns_B = data_tns_290_B[0,:]
mean_tumble_M = data_tumble_290_M[0,:]
mean_tns_M = data_tns_290_M[0,:]
mean_tumble_B = data_tumble_290_B[0,:]

std_tns_B = data_tns_290_B[1,:]
std_tumble_M = data_tumble_290_M[1,:]
std_tns_M = data_tns_290_M[1,:]
std_tumble_B = data_tumble_290_B[1,:]

sterr_tns_B = data_tns_290_B[2,:]
sterr_tumble_M = data_tumble_290_M[2,:]
sterr_tns_M = data_tns_290_M[2,:]
sterr_tumble_B = data_tumble_290_B[2,:]

t_tns_B = data_tns_290_B[3,:]
t_tumble_B = data_tumble_290_B[3,:]
t_tns_M = data_tns_290_M[3,:]
t_tumble_M = data_tumble_290_M[3,:]

fig, ax = plt.subplots(1, 2, figsize=(12, 5), sharey=True)


ax[0].plot(t_tumble_M, mean_tumble_M, label='tumbling ', color='red', alpha=1)
ax[1].plot(t_tumble_B, mean_tumble_B, label='tumbling', color='red', alpha=1)

ax[0].plot(t_tns_M, mean_tns_M, label='tumbling and spinning', color='orange', alpha=1)
ax[1].plot(t_tns_B, mean_tns_B, label='tumbling and spinning ', color='orange', alpha=1)

ax[0].set_title('benzene and methanol mix autocorrelation function')
ax[1].set_title('benzene autocorrelation function')

ax[0].set_xlabel('time / ps')
ax[1].set_xlabel('time / ps')

ax[0].set_ylabel('rotation autocorrelation function')
ax[1].set_ylabel('rotation autocorrelation function')
ax[0].legend()
ax[1].legend()
